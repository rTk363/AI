# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("TITANIC.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Problem Statement

# %%
print("Problem Statement")
print("The survived passengers are: ")
data[data['Survived'] == 1]['Name']

# %% [markdown]
# ## Part I

# %%
print("The no of children who didnt survive")
data[(data['Survived']==0) & (data['Age']<18)][['Name','Age']]

# %%
print("The no of women who didnt survive")
data[(data['Survived']==0) & (data['Sex']=='female') & (data['Age']>=18)][['Name','Age','Sex']]
# Out:
# The no of women who didnt survive
#                                                   Name   Age     Sex
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0  female
# 38                  Vander Planke, Miss. Augusta Maria  18.0  female
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0  female
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  27.0  female
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  18.0  female
# 100                            Petranec, Miss. Matilda  28.0  female
# 113                            Jussila, Miss. Katriina  20.0  female
# 132     Robins, Mrs. Alexander A (Grace Charity Laury)  47.0  female
# 167    Skoog, Mrs. William (Anna Bernhardina Karlsson)  45.0  female
# 177                         Isham, Miss. Ann Elizabeth  50.0  female
# 199             Yrois, Miss. Henriette ("Mrs Harbeck")  24.0  female
# 246              Lindahl, Miss. Agda Thorilda Viktoria  25.0  female
# ...

# %%
print("The no of Upper class people who didnt survive")
data[(data['Survived']==0) & (data['Pclass']==3)][['Name','Pclass','Sex']]
# Out:
# The no of Upper class people who didnt survive
#                                          Name  Pclass     Sex
# 0                     Braund, Mr. Owen Harris       3    male
# 4                    Allen, Mr. William Henry       3    male
# 5                            Moran, Mr. James       3    male
# 7              Palsson, Master. Gosta Leonard       3    male
# 12             Saundercock, Mr. William Henry       3    male
# ..                                        ...     ...     ...
# 882              Dahlberg, Miss. Gerda Ulrika       3  female
# 884                    Sutehall, Mr. Henry Jr       3    male
# 885      Rice, Mrs. William (Margaret Norton)       3  female
# 888  Johnston, Miss. Catherine Helen "Carrie"       3  female
# 890                       Dooley, Mr. Patrick       3    male
#
# [372 rows x 3 columns]

# %% [markdown]
# ## Part II

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue='Sex')

# %%
sns.barplot(x='Sex',y='Survived',data=data)
print("This shows that no of Females had survived more than that of males")
# Out:
# This shows that no of Females had survived more than that of males

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Survived',y='Age',data=data,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=data,x='Survived',y='Embarked',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Embarked'>

# %%
sns.scatterplot(data=data,x='Age',y='Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.boxplot(data=data,x='Pclass',y='Fare')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>
